# %%
import pandas as pd

# %%
json = pd.read_json('tracks.json')

# %%
json = json[json['primary_artist'] == 'Dark Polo Gang']

# %%
json.head()
# Out:
#             id    id_artist           title featured_artists  primary_artist  \
# 8983  TR377717  ART96068455       Cavallini    Sfera Ebbasta  Dark Polo Gang
# 8984  TR873361  ART96068455      Sportswear             None  Dark Polo Gang
# 8985  TR156840  ART96068455  Fiori Del Male    Sfera Ebbasta  Dark Polo Gang
# 8986  TR948244  ART96068455     Cono Gelato             None  Dark Polo Gang
# 8987  TR423996  ART96068455       Caramelle     Marïna (ITA)  Dark Polo Gang
#
#      language           album  swear_IT  swear_EN  \
# 8983       it    Crack Musica         5         4
# 8984       en  The Dark Album         5         0
# 8985       pl  The Dark Album         3         0
# 8986       it           Twins         6         5
# 8987       pl           Twins         6         0
#
#                                 swear_IT_words  ... album_release_date  \
# 8983  ['cagna', 'fottere', 'stronzo', 'troia']  ...         2016-03-10
# ...

# %%
json.columns
# Out:
# Index(['id', 'id_artist', 'title', 'featured_artists', 'primary_artist',
#        'language', 'album', 'swear_IT', 'swear_EN', 'swear_IT_words',
#        'swear_EN_words', 'year', 'month', 'day', 'n_sentences', 'n_tokens',
#        'char_per_tok', 'avg_token_per_clause', 'bpm', 'rolloff', 'flux', 'rms',
#        'flatness', 'spectral_complexity', 'pitch', 'loudness', 'album_name',
#        'album_release_date', 'album_type', 'disc_number', 'track_number',
#        'duration_ms', 'explicit', 'popularity', 'id_album', 'lyrics',
#        'streams@1month'],
#       dtype='object')

# %%
json['featured_artists'].unique()
# Out:
# array(['Ernia, Guè', 'Thelonious B.', 'MamboLosco, RADICAL', ...,
#        'Aban, Ted Bee', 'Il Nano, Izio Sklero', 'Misa'], dtype=object)
