# %%
import pandas as pd

# %%
json = pd.read_json('tracks.json')

# %%
json.head(20)
# Out:
#           id    id_artist           title     featured_artists primary_artist  \
# 0   TR934808  ART04205421    ​polka 2 :-/           Ernia, Guè  Rosa Chemical
# 1   TR760029  ART04205421           POLKA        Thelonious B.  Rosa Chemical
# 2   TR916821  ART04205421    ​britney ;-)  MamboLosco, RADICAL  Rosa Chemical
# 3   TR480968  ART04205421             CEO               Taxi B  Rosa Chemical
# 4   TR585039  ART04205421          LONDRA                Rkomi  Rosa Chemical
# 5   TR550335  ART04205421          BOHEME                 None  Rosa Chemical
# 6   TR170793  ART04205421       LOBBY WAY                 None  Rosa Chemical
# 7   TR627195  ART04205421           SLATT            Dani Faiv  Rosa Chemical
# 8   TR628871  ART04205421   MADE IN ITALY                 None  Rosa Chemical
# 9   TR700756  ART04205421     ROSE & ROVI                 None  Rosa Chemical
# 10  TR570242  ART04205421         POLKA 3                 None  Rosa Chemical
# ...

# %%
json.shape
# Out:
# (11166, 37)

# %%
json.dtypes
# Out:
# id                       object
# id_artist                object
# title                    object
# featured_artists         object
# primary_artist           object
# language                 object
# album                    object
# swear_IT                  int64
# swear_EN                  int64
# swear_IT_words           object
# swear_EN_words           object
# year                    float64
# month                   float64
# day                     float64
# n_sentences             float64
# n_tokens                float64
# char_per_tok            float64
# avg_token_per_clause    float64
# bpm                     float64
# rolloff                 float64
# flux                    float64
# rms                     float64
# flatness                float64
# spectral_complexity     float64
# pitch                   float64
# loudness                float64
# album_name               object
# album_release_date       object
# album_type               object
# ...

# %%
json.isnull().sum()
# Out:
# id                         0
# id_artist                  0
# title                      0
# featured_artists        7649
# primary_artist             0
# language                 105
# album                   1514
# swear_IT                   0
# swear_EN                   0
# swear_IT_words             0
# swear_EN_words             0
# year                     444
# month                   1197
# day                     1323
# n_sentences               76
# n_tokens                  76
# char_per_tok              76
# avg_token_per_clause      76
# bpm                       64
# rolloff                   64
# flux                      64
# rms                       64
# flatness                  64
# spectral_complexity       64
# pitch                     64
# loudness                  64
# album_name                78
# album_release_date        78
# album_type                78
# disc_number               78
# track_number              78
# duration_ms               78
# ...

# %%
json.nunique()
# Out:
# id                      11093
# id_artist                 104
# title                   10521
# featured_artists         1740
# primary_artist            104
# language                   35
# album                     890
# swear_IT                   44
# swear_EN                   40
# swear_IT_words           2659
# swear_EN_words            535
# year                       34
# month                      12
# day                        31
# n_sentences               176
# n_tokens                 1063
# char_per_tok             9844
# avg_token_per_clause     7569
# bpm                      4119
# rolloff                 10785
# flux                     4633
# rms                      2775
# flatness                 2536
# spectral_complexity     10579
# pitch                   10782
# loudness                10561
# album_name               2421
# album_release_date       1390
# album_type                  3
# disc_number                 5
# track_number               39
# ...

# %%
# Duplicati basati su entrambe le colonne contemporaneamente
json[json.duplicated(subset=['title', 'primary_artist'], keep=False)]
# Out:
#             id    id_artist     title   featured_artists primary_artist  \
# 4627  TR367132  ART20729624     BUGIE  Rkomi, Carl Brave         Madame
# 4628  TR367132  ART20729624     BUGIE  Rkomi, Carl Brave         Madame
# 4647  TR367132  ART20729624  ​sentimi               None         Madame
# 4648  TR367132  ART20729624  ​sentimi               None         Madame
#
#      language   album  swear_IT  swear_EN swear_IT_words  ...  \
# 4627       it  MADAME         0         0             []  ...
# 4628       it  MADAME         0         0             []  ...
# 4647       it    None         0         0             []  ...
# 4648       it    None         0         0             []  ...
#
#      album_release_date  album_type  disc_number  track_number  duration_ms  \
# 4627         2021-06-03       album          1.0           6.0     171602.0
# 4628         2020-04-24      single          1.0           1.0     187660.0
# ...

# %%
json['primary_artist'].value_counts()
# Out:
# primary_artist
# Mondo Marcio     353
# Guè              333
# Gemitaiz         333
# Bassi Maestro    279
# Fabri Fibra      275
#                 ...
# Mistico            4
# Hindaco            3
# Miss Simpatia      3
# Joey (ITA)         3
# ’O Zulù            2
# Name: count, Length: 104, dtype: int64

# %%
json = json[json['language'].isnull()]

# %%
pd.set_option('display.max_columns', None)
json.head(50)
# Out:
#             id    id_artist                              title  \
# 198   TR420842  ART88026810                 ​blun7 a swishland
# 268   TR481273  ART88026810                       I.B.F.M. rmx
# 627   TR761374  ART62385172                                 R9
# 646   TR196840  ART62385172                  Street Banger RMX
# 664   TR477378  ART62385172                  Tre Mani Di Donna
# 668   TR991112  ART62385172              Another Day My Blocco
# 670   TR971575  ART62385172                          Au Chante
# 696   TR607983  ART24123617                       La Mia Queen
# 715   TR565835  ART24123617                        Ma Ormai...
# 721   TR603906  ART24123617                           Lo Sanno
# 727   TR502373  ART24123617            Intro (come un uragano)
# 739   TR837894  ART24123617                        Sua Volontà
# 1292  TR680539  ART70825116                            No Game
# 1748  TR913780  ART71969350                    Hannibal rapper
# ...
