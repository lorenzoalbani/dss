# %%
# pip install lxml

# %%
import pandas as pd

# %%
# Lettura semplice
df = pd.read_xml('artists.xml')

df
# Out:
#        id_author           name gender  birth_date      birth_place  \
# 0    ART82291002       99 posse      M        None             None
# 1    ART53496045  achille lauro      M  1990-07-11           Verona
# 2    ART18853907           alfa      M        None             None
# 3    ART64265460      anna pepe      F        None             None
# 4    ART75741740    articolo 31      M        None             None
# ..           ...            ...    ...         ...              ...
# 99   ART98118784       tormento      M  1975-09-06  Reggio Calabria
# 100  ART15560128          vacca      M  1979-10-21         Cagliari
# 101  ART57587384  willie peyote      M  1985-08-28           Torino
# 102  ART71515715         yeиdry      F        None             None
# 103  ART83631935     yung snapp      M  1996-08-06           Napoli
#
#     nationality                                      description active_start  \
# ...

# %%
df.columns
# Out:
# Index(['id_author', 'name', 'gender', 'birth_date', 'birth_place',
#        'nationality', 'description', 'active_start', 'active_end', 'province',
#        'region', 'country', 'latitude', 'longitude'],
#       dtype='object')
