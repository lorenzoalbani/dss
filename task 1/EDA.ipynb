# %% [markdown]
# # EDA tracks.json

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
ds = pd.read_json('tracks.json')

# %%
ds.head(3)
# Out:
#          id    id_artist         title     featured_artists primary_artist  \
# 0  TR934808  ART04205421  ​polka 2 :-/           Ernia, Guè  Rosa Chemical
# 1  TR760029  ART04205421         POLKA        Thelonious B.  Rosa Chemical
# 2  TR916821  ART04205421  ​britney ;-)  MamboLosco, RADICAL  Rosa Chemical
#
#   language             album  swear_IT  swear_EN  \
# 0       pl  FOREVER AND EVER        13         6
# 1       en  FOREVER AND EVER         9        12
# 2       en  FOREVER AND EVER        16        12
#
#                                       swear_IT_words  ... album_release_date  \
# 0  ['cazzo', 'cesso', 'coglioni', 'figa', 'merda'...  ...         2021-04-09
# 1  ['cazzo', 'culo', 'frocio', 'puttana', 'sega',...  ...         2021-04-09
# 2    ['bastardo', 'cazzo', 'culo', 'merda', 'troia']  ...         2021-04-09
#
#    album_type  disc_number  track_number  duration_ms  explicit  popularity  \
# 0       album          1.0           3.0     207761.0       1.0        46.0
# 1       album          1.0           3.0     207761.0       1.0        46.0
# 2       album          1.0           1.0     193544.0       1.0        39.0
#
#     id_album                                             lyrics  \
# 0  ALB115557  Oplà, ah\nBdope, chiama due b—\n\nMi candidere...
# 1  ALB115557  Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...
# 2  ALB115557  Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...
#
#    streams@1month
# 0          186522
# 1          194313
# 2           63750
#
# [3 rows x 37 columns]

# %%
ds.describe()
# Out:
#            swear_IT      swear_EN          year        month          day  \
# count  11166.000000  11166.000000  10722.000000  9969.000000  9843.000000
# mean       2.343006      0.711177   2015.135796     6.198515    15.808697
# std        3.704831      2.555423      7.022598     3.482992     8.881989
# min        0.000000      0.000000   1992.000000     1.000000     1.000000
# 25%        0.000000      0.000000   2011.000000     3.000000     9.000000
# 50%        1.000000      0.000000   2016.000000     6.000000    16.000000
# 75%        3.000000      0.000000   2021.000000    10.000000    23.000000
# max       72.000000     72.000000   2025.000000    12.000000    31.000000
#
#         n_sentences      n_tokens  char_per_tok  avg_token_per_clause  \
# count  11090.000000  11090.000000  11090.000000          11090.000000
# mean      59.399639    496.891253      4.054416              8.002009
# std       24.711996    209.187612      0.445958             14.577876
# min        1.000000      3.000000      2.000000              0.000000
# 25%       46.000000    372.000000      3.866946              5.859020
# 50%       58.000000    491.000000      4.012709              6.764171
# 75%       73.000000    615.000000      4.168686              8.090909
# max      437.000000   3089.000000     12.000000            660.000000
#
#                 bpm       rolloff          flux           rms      flatness  \
# count  11102.000000  11102.000000  11102.000000  11102.000000  11102.000000
# mean     114.134841   1616.965767      1.258893      0.223965      0.859986
# std       26.827124    567.646409      0.137123      0.064592      0.109106
# min       59.970000      0.000000      0.000000      0.000000      0.109400
# 25%       91.910000   1222.457200      1.172025      0.186225      0.841400
# 50%      106.975000   1551.018550      1.257100      0.229700      0.882450
# 75%      134.650000   1935.570650      1.346875      0.267600      0.913075
# max      738.270000   8635.954200      1.928500      0.621900      1.000000
#
#        spectral_complexity         pitch      loudness   disc_number  \
# count         11102.000000  11102.000000  11102.000000  11088.000000
# mean             27.410247   2256.028782     24.226955      1.016685
# std               8.441590    382.134853      8.648780      0.138903
# min               0.000000      0.000000      0.000000      1.000000
# 25%              21.881750   2003.341325     18.779500      1.000000
# 50%              27.330850   2241.157450     24.666850      1.000000
# 75%              32.978475   2493.492250     30.010175      1.000000
# max              61.222500   3993.020300     81.947800      5.000000
#
#        track_number   duration_ms      explicit    popularity  streams@1month
# count  11088.000000  1.108800e+04  11088.000000  11088.000000    1.116600e+04
# mean       6.859127  2.035293e+05      0.507666     32.656295    1.821737e+04
# std        5.191472  8.825641e+04      0.499964     19.781473    3.903201e+04
# min        1.000000  1.142600e+04      0.000000      0.000000    4.011000e+03
# 25%        2.000000  1.701310e+05      0.000000     16.000000    4.835000e+03
# 50%        6.000000  1.966725e+05      1.000000     32.000000    5.644500e+03
# 75%       10.000000  2.271840e+05      1.000000     47.000000    1.423925e+04
# max       54.000000  3.753057e+06      1.000000    100.000000    1.501925e+06

# %%
ds.shape
# Out:
# (11166, 37)

# %%
ds.dtypes
# Out:
# id                       object
# id_artist                object
# title                    object
# featured_artists         object
# primary_artist           object
# language                 object
# album                    object
# swear_IT                  int64
# swear_EN                  int64
# swear_IT_words           object
# swear_EN_words           object
# year                    float64
# month                   float64
# day                     float64
# n_sentences             float64
# n_tokens                float64
# char_per_tok            float64
# avg_token_per_clause    float64
# bpm                     float64
# rolloff                 float64
# flux                    float64
# rms                     float64
# flatness                float64
# spectral_complexity     float64
# pitch                   float64
# loudness                float64
# album_name               object
# album_release_date       object
# album_type               object
# disc_number             float64
# track_number            float64
# duration_ms             float64
# explicit                float64
# popularity              float64
# id_album                 object
# lyrics                   object
# streams@1month            int64
# dtype: object

# %%
print(ds.columns)
# Out:
# Index(['id', 'id_artist', 'title', 'featured_artists', 'primary_artist',
#        'language', 'album', 'swear_IT', 'swear_EN', 'swear_IT_words',
#        'swear_EN_words', 'year', 'month', 'day', 'n_sentences', 'n_tokens',
#        'char_per_tok', 'avg_token_per_clause', 'bpm', 'rolloff', 'flux', 'rms',
#        'flatness', 'spectral_complexity', 'pitch', 'loudness', 'album_name',
#        'album_release_date', 'album_type', 'disc_number', 'track_number',
#        'duration_ms', 'explicit', 'popularity', 'id_album', 'lyrics',
#        'streams@1month'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# id                         0
# id_artist                  0
# title                      0
# featured_artists        7649
# primary_artist             0
# language                 105
# album                   1514
# swear_IT                   0
# swear_EN                   0
# swear_IT_words             0
# swear_EN_words             0
# year                     444
# month                   1197
# day                     1323
# n_sentences               76
# n_tokens                  76
# char_per_tok              76
# avg_token_per_clause      76
# bpm                       64
# rolloff                   64
# flux                      64
# rms                       64
# flatness                  64
# spectral_complexity       64
# pitch                     64
# loudness                  64
# album_name                78
# album_release_date        78
# album_type                78
# disc_number               78
# track_number              78
# duration_ms               78
# explicit                  78
# popularity                78
# id_album                  78
# lyrics                     3
# streams@1month             0
# dtype: int64

# %%
ds.nunique()
# Out:
# id                      11093
# id_artist                 104
# title                   10521
# featured_artists         1740
# primary_artist            104
# language                   35
# album                     890
# swear_IT                   44
# swear_EN                   40
# swear_IT_words           2659
# swear_EN_words            535
# year                       34
# month                      12
# day                        31
# n_sentences               176
# n_tokens                 1063
# char_per_tok             9844
# avg_token_per_clause     7569
# bpm                      4119
# rolloff                 10785
# flux                     4633
# rms                      2775
# flatness                 2536
# spectral_complexity     10579
# pitch                   10782
# loudness                10561
# album_name               2421
# album_release_date       1390
# album_type                  3
# disc_number                 5
# track_number               39
# duration_ms              7910
# explicit                    2
# popularity                 97
# id_album                 3061
# lyrics                  11153
# streams@1month           6010
# dtype: int64

# %%
ds['primary_artist'].value_counts()
# Out:
# primary_artist
# Mondo Marcio     353
# Guè              333
# Gemitaiz         333
# Bassi Maestro    279
# Fabri Fibra      275
#                 ...
# Mistico            4
# Hindaco            3
# Miss Simpatia      3
# Joey (ITA)         3
# ’O Zulù            2
# Name: count, Length: 104, dtype: int64

# %%
# raggruppo per artista e calcolo avg_streams = sum(streams)/count(tracks)
top_artists = (ds.groupby('primary_artist')
               .agg({'streams@1month': 'sum', 'id': 'count'})
               .assign(avg_streams=lambda x: x['streams@1month'] / x['id'])
               .sort_values('avg_streams', ascending=False)
               .head(10))

# plotto avg_streams per track
top_artists['avg_streams'].plot(kind='bar', figsize=(10,6), color='green', edgecolor='black')
plt.title('Top 10 Artisti: Streams Medi per Traccia')
plt.ylabel('Streams Medi per Traccia')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
null_lang = ds[ds['language'].isnull()]

# %%
pd.set_option('display.max_columns', None)
null_lang.head(500)
# Out:
#              id    id_artist                title featured_artists  \
# 198    TR420842  ART88026810   ​blun7 a swishland             None
# 268    TR481273  ART88026810         I.B.F.M. rmx  Lazza, Low Kidd
# 627    TR761374  ART62385172                   R9             None
# 646    TR196840  ART62385172    Street Banger RMX             None
# 664    TR477378  ART62385172    Tre Mani Di Donna             None
# ...         ...          ...                  ...              ...
# 8714   TR986994  ART59609037       Sto Cor Veleno             None
# 8757   TR740772  ART59609037   Esplosivo (K.O.B.)         Roy Paci
# 8784   TR978315  ART59609037               Filtri      Pier Velvet
# 9086   TR988416  ART96068455  Young Rich Gang RMX      City Morgue
# 10129  TR732834  ART64850829                 Amen             None
#
#        primary_artist language                 album  swear_IT  swear_EN  \
# 198            thasup     None               23 6451         0         0
# 268            thasup     None                  None         5         0
# 627            Nerone     None             N Mixtape         2         1
# 646            Nerone     None             N Mixtape         5         3
# 664            Nerone     None             N Mixtape         0         0
# ...               ...      ...                   ...       ...       ...
# 8714       Cor Veleno     None            Buona Pace         1         0
# 8757       Cor Veleno     None           Nuovo Nuovo         0         0
# 8784       Cor Veleno     None           Pace Armata         1         0
# 9086   Dark Polo Gang     None  Trap Lovers Reloaded         1        31
# 10129           Shiva     None                  None         1         0
#
#                     swear_IT_words  \
# 198                             []
# 268     ['cazzo', 'culo', 'troia']
# 627     ['coglioni', 'vaffanculo']
# 646    ['cazzo', 'merda', 'pippa']
# 664                             []
# ...                            ...
# 8714                      ['culo']
# 8757                            []
# 8784                ['vaffanculo']
# 9086                   ['stupida']
# 10129                    ['cazzo']
#
#                                           swear_EN_words    year  month   day  \
# 198                                                   []  2019.0   11.0   8.0
# 268                                                   []  2018.0    4.0   1.0
# 627                                              ['fag']  2016.0    2.0  22.0
# 646                        ['hardcore', 'negro', 'shit']  2016.0    2.0  22.0
# 664                                                   []     NaN    NaN   NaN
# ...                                                  ...     ...    ...   ...
# 8714                                                  []  2010.0    5.0  24.0
# 8757                                                  []  2007.0    2.0  16.0
# 8784                                                  []  2009.0   12.0  17.0
# 9086   ['bitch', 'bitches', 'dick', 'fuck', 'playboy'...  2019.0    5.0  24.0
# 10129                                                 []  2016.0    5.0  26.0
#
#        n_sentences  n_tokens  char_per_tok  avg_token_per_clause     bpm  \
# 198           43.0     482.0      3.979058              7.531250  129.99
# 268           81.0     611.0      3.699571              9.257576  123.76
# 627           99.0     422.0      4.031325              7.814815   94.59
# 646           42.0     355.0      4.206897              7.717391   94.85
# 664           25.0     243.0      4.098655              8.379310  137.37
# ...            ...       ...           ...                   ...     ...
# 8714          84.0     581.0      3.652510              8.300000  150.04
# 8757          44.0     399.0      3.971722              7.125000   89.98
# 8784          53.0     485.0      3.810870              7.461538   87.94
# 9086         107.0     821.0      4.058626             23.457143  125.99
# 10129         35.0     214.0      4.358586              5.944444  105.90
#
#          rolloff    flux     rms  flatness  spectral_complexity      pitch  \
# 198    1805.2343  1.3294  0.1935    0.8826              23.7241  2362.5395
# 268    2848.4567  1.4189  0.3709    0.6510              49.5239  2425.5779
# 627    1137.6445  1.5725  0.4072    0.8933              26.0261  2948.9399
# 646    1279.0594  1.6417  0.3188    0.9046              24.2198  2800.8910
# 664    1569.2784  1.4609  0.2843    0.8687              28.5527  2258.7488
# ...          ...     ...     ...       ...                  ...        ...
# 8714   1370.0545  1.1609  0.1714    0.8800              24.0178  2423.7691
# 8757   2092.5617  1.4590  0.2452    0.7899              32.9263  2155.3908
# 8784   1386.2216  1.2498  0.1995    0.8717              21.8372  2920.6322
# 9086   1796.6724  1.2080  0.2865    0.7945              36.7669  2695.7127
# 10129  1576.4077  1.3212  0.2222    0.8697              21.7326  2398.0316
#
#        loudness                                   album_name  \
# 198     20.0809                                      23 6451
# 268     45.3114                                      23 6451
# 627     50.7062                                    N Mixtape
# 646     37.5830                                    N Mixtape
# 664     32.1416                                    N Mixtape
# ...         ...                                          ...
# 8714    17.2738                                   Buona Pace
# 8757    27.0660                                  Nuovo Nuovo
# 8784    20.2534                               B.B.C. Project
# 9086    33.0485                       Trap Lovers (Reloaded)
# 10129   24.2354  Maha Shivaratri 2021: Sai Young Adults Open
#
#       album_release_date album_type  disc_number  track_number  duration_ms  \
# 198           2019-11-15      album          1.0           7.0     167760.0
# 268           2019-11-15      album          1.0           3.0     161266.0
# 627           2016-02-22      album          1.0           5.0     132675.0
# 646           2016-02-22      album          1.0          11.0     101407.0
# 664           2016-02-22      album          1.0           9.0      69015.0
# ...                  ...        ...          ...           ...          ...
# 8714          2010-05-25      album          1.0           9.0     239053.0
# 8757          2007-02-16      album          1.0           6.0     193666.0
# 8784          2011-03-28     single          1.0           1.0     199866.0
# 9086          2019-05-24      album          1.0           4.0     253671.0
# 10129         2021-03-11      album          1.0           9.0     157588.0
#
#        explicit  popularity   id_album  \
# 198         1.0        56.0  ALB530526
# 268         1.0        59.0  ALB530526
# 627         0.0        10.0  ALB815648
# 646         0.0        12.0  ALB815648
# 664         0.0         9.0  ALB815648
# ...         ...         ...        ...
# 8714        0.0        14.0  ALB946942
# 8757        0.0         4.0  ALB709013
# 8784        1.0        50.0  ALB307363
# 9086        1.0        23.0  ALB219122
# 10129       0.0         2.0  ALB950357
#
#                                                   lyrics  streams@1month
# 198    Yeah\n\nSwisho un blunt a Swishland, bling bla...          524979
# 268    Il brano è un remix di “IBFM” di Lazza e Low K...            4733
# 627    Biggie Paul al beat\nNerone\nR9\n9x\nZona 4\nM...            5510
# 646    Pepito Rella production\nStreet Banger\nNerone...            5200
# 664    E ancora Biggie Paul, Mcf\nTre mani di donna, ...            4215
# ...                                                  ...             ...
# 8714   Cor Veleno, Cor Veleno\nEh, eh\nCor Veleno, Co...            5795
# 8757   King of the bongo \n\nEsplosivo e non so se fu...            4670
# 8784   Il brano vanta la collaborazione di Pier Velve...            5148
# 9086   Sick Luke, Sick Luke\nEhi, ehi, ehi\nUoh (uoh,...            8993
# 10129  Odio il mio essere, godo a vedermi perdere\nPe...            5379
#
# [105 rows x 37 columns]

# %%
# controllo tracce con lo stesso id
conteggi = ds['id'].value_counts()

duplicati = conteggi[conteggi > 1]

print(duplicati)
# Out:
# id
# TR367132    4
# TR898853    2
# TR621186    2
# TR503521    2
# TR192351    2
#            ..
# TR427122    2
# TR261964    2
# TR386339    2
# TR825208    2
# TR997536    2
# Name: count, Length: 71, dtype: int64

# %%
# vedo gli ID assegnati a tracce diverse che abbiamo scoperto prima

duplicati = ds[ds.duplicated(subset=['id'], keep=False)]

conteggio_titoli = duplicati.groupby('id')['title'].nunique()
ids_con_titoli_diversi = conteggio_titoli[conteggio_titoli > 1].index

print(f"Number of ids that have different titles between their copies: {len(ids_con_titoli_diversi)}")

if len(ids_con_titoli_diversi) > 0:
    cols_to_show = ['id', 'title', 'primary_artist', 'album']
    display(ds[ds['id'].isin(ids_con_titoli_diversi)].sort_values('id')[cols_to_show])
# Out:
# Number of ids that have different titles between their copies: 71
#              id                   title    primary_artist  \
# 4240   TR108862               Sushi Bar     Bassi Maestro
# 7786   TR108862                   SPINE       Noyz Narcos
# 3199   TR135764  Nessuno vale quanto te            Ghemon
# 5847   TR135764            Giovani eroi        Emis Killa
# 8104   TR190585      Nei treni la notte              Coez
# ...         ...                     ...               ...
# 2474   TR980497         Te-le-co-man-do          Mistaman
# 4190   TR987615            Django Muzik     Bassi Maestro
# 1318   TR987615               Polo Nord  Massimo Pericolo
# 10375  TR997536               Vida Loca      Mondo Marcio
# 9952   TR997536     L’oracolo di Selfie             Nitro
#
#                         album
# 4240                 Sushi EP
# 7786           VIRUS (Deluxe)
# 3199                 ORCHIdee
# 5847       Keta Music, Vol. 3
# 8104       From The Rooftop 2
# ...                       ...
# 2474          Anni senza fine
# 4190          Guarda In Cielo
# 1318                     None
# 10375                   UOMO!
# 9952   Suicidol - Post Mortem
#
# [144 rows x 4 columns]

# %%
# Cerco canzoni duplicate (uso come chavi titolo e artista)
ds[ds.duplicated(subset=['title', 'primary_artist'], keep=False)]
# Out:
#             id    id_artist     title   featured_artists primary_artist  \
# 4627  TR367132  ART20729624     BUGIE  Rkomi, Carl Brave         Madame
# 4628  TR367132  ART20729624     BUGIE  Rkomi, Carl Brave         Madame
# 4647  TR367132  ART20729624  ​sentimi               None         Madame
# 4648  TR367132  ART20729624  ​sentimi               None         Madame
#
#      language   album  swear_IT  swear_EN swear_IT_words swear_EN_words  \
# 4627       it  MADAME         0         0             []             []
# 4628       it  MADAME         0         0             []             []
# 4647       it    None         0         0             []             []
# 4648       it    None         0         0             []             []
#
#         year  month   day  n_sentences  n_tokens  char_per_tok  \
# 4627  2021.0    3.0  19.0         47.0     268.0      4.047619
# 4628  2021.0    3.0  19.0         47.0     268.0      4.047619
# 4647  2020.0    4.0  24.0         47.0     268.0      4.047619
# 4648  2020.0    4.0  24.0         47.0     268.0      4.047619
#
#       avg_token_per_clause     bpm   rolloff    flux     rms  flatness  \
# 4627              5.056604  125.96  971.3151  1.0464  0.1782    0.9049
# 4628              5.056604  125.96  971.3151  1.0464  0.1782    0.9049
# 4647              5.056604  125.96  971.3151  1.0464  0.1782    0.9049
# 4648              5.056604  125.96  971.3151  1.0464  0.1782    0.9049
#
#       spectral_complexity      pitch  loudness album_name album_release_date  \
# 4627              15.2131  2520.5922   17.9408     MADAME         2021-06-03
# 4628              15.2131  2520.5922   17.9408    sentimi         2020-04-24
# 4647              15.2131  2520.5922   17.9408     MADAME         2021-06-03
# 4648              15.2131  2520.5922   17.9408    sentimi         2020-04-24
#
#      album_type  disc_number  track_number  duration_ms  explicit  popularity  \
# 4627      album          1.0           6.0     171602.0       0.0        48.0
# 4628     single          1.0           1.0     187660.0       0.0        42.0
# 4647      album          1.0           6.0     171602.0       0.0        48.0
# 4648     single          1.0           1.0     187660.0       0.0        42.0
#
#        id_album                                             lyrics  \
# 4627  ALB468764  E visto che non so dire di no\nSintomi da star...
# 4628  ALB590629  E visto che non so dire di no\nSintomi da star...
# 4647  ALB468764  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...
# 4648  ALB590629  Eh-eh-ah\nSiedi e sentimi\nYeah\n\nSiedi e sen...
#
#       streams@1month
# 4627           36965
# 4628           39108
# 4647           12626
# 4648           16106

# %%
# Vedo se ci sono album con più di un primary artist assegnato
duplicati = ds.groupby('album').filter(lambda x: x['primary_artist'].nunique() > 1)

risultato = duplicati[['album', 'primary_artist', 'title']].drop_duplicates().sort_values('album')

pd.set_option('display.max_rows', None)

risultato.head(200)
# Out:
#                                                    album     primary_artist  \
# 5839                                   17 (Dark Edition)         Emis Killa
# 5792                                   17 (Dark Edition)         Emis Killa
# 5766                                   17 (Dark Edition)         Emis Killa
# 5787                                   17 (Dark Edition)         Emis Killa
# 5793                                   17 (Dark Edition)         Emis Killa
# 5800                                   17 (Dark Edition)         Emis Killa
# 5806                                   17 (Dark Edition)         Emis Killa
# 5825                                   17 (Dark Edition)         Emis Killa
# 5831                                   17 (Dark Edition)         Emis Killa
# 5842                                   17 (Dark Edition)         Emis Killa
# 5845                                   17 (Dark Edition)         Emis Killa
# 5846                                   17 (Dark Edition)         Emis Killa
# 2699                                   17 (Dark Edition)      Jake La Furia
# 5782                                   17 (Dark Edition)         Emis Killa
# 5779                                   17 (Dark Edition)         Emis Killa
# 5784                                   17 (Dark Edition)         Emis Killa
# 5778                                   17 (Dark Edition)         Emis Killa
# 5777                                   17 (Dark Edition)         Emis Killa
# 5767                                   17 (Dark Edition)         Emis Killa
# 5768                                   17 (Dark Edition)         Emis Killa
# 5774                                   17 (Dark Edition)         Emis Killa
# 5772                                   17 (Dark Edition)         Emis Killa
# 5770                                   17 (Dark Edition)         Emis Killa
# 5769                                   17 (Dark Edition)         Emis Killa
# 4881                                          21 Motivi               Vacca
# 9858                                          21 Motivi            Tormento
# 8146                                          21 Motivi                Coez
# 8334                                          21 Motivi              MadMan
# 7358                                          21 Motivi            Gemitaiz
# 9183                                       50 eMCee’s II  Colle Der Fomento
# 4261                                       50 eMCee’s II      Bassi Maestro
# 2633                                              5° Dan              Inoki
# 2614                                              5° Dan              Inoki
# 2613                                              5° Dan              Inoki
# 2611                                              5° Dan              Inoki
# 2621                                              5° Dan              Inoki
# 2595                                              5° Dan              Inoki
# 2560                                              5° Dan              Inoki
# 2583                                              5° Dan              Inoki
# 2575                                              5° Dan              Inoki
# 2561                                              5° Dan              Inoki
# 2557                                              5° Dan              Inoki
# 2541                                              5° Dan              Inoki
# 2590                                              5° Dan              Inoki
# 8159                                              5° Dan             Shablo
# 9720                    BLOCCO 181 - ORIGINAL SOUNDTRACK              Salmo
# 914                     BLOCCO 181 - ORIGINAL SOUNDTRACK                Guè
# 7808                    BLOCCO 181 - ORIGINAL SOUNDTRACK        Noyz Narcos
# 6566                    BLOCCO 181 - ORIGINAL SOUNDTRACK              Ernia
# 425                     BLOCCO 181 - ORIGINAL SOUNDTRACK              Lazza
# 2701                    BLOCCO 181 - ORIGINAL SOUNDTRACK      Jake La Furia
# 4499                    BLOCCO 181 - ORIGINAL SOUNDTRACK               Ensi
# 9749                    BLOCCO 181 - ORIGINAL SOUNDTRACK              Salmo
# 554                     BLOCCO 181 - ORIGINAL SOUNDTRACK             Nerone
# 4612                            Beatbox Selection Vol. 1               Ensi
# 10630                           Beatbox Selection Vol. 1       Mondo Marcio
# 5517                            Beatbox Selection Vol. 1     Dargen D’Amico
# 6401                            Beatbox Selection Vol. 1             Entics
# 5983                            Beatbox Selection Vol. 1         Emis Killa
# 6258                                 Beats From The Lido      Willie Peyote
# 1156                                 Beats From The Lido            Mudimbi
# 5993                                        Bella Lucio!         Emis Killa
# 4595                                        Bella Lucio!               Ensi
# 10580                                       Bella Lucio!       Mondo Marcio
# 3317                                        Bella Lucio!             Ghemon
# 7885                                Benvenuti In Borgata        Noyz Narcos
# 11154                               Benvenuti In Borgata          Marracash
# 7491                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7509                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7508                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7498                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7502                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7503                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7504                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7505                         Bloody Vinyl Mixtape Vol. 1              Slait
# 7507                         Bloody Vinyl Mixtape Vol. 1              Slait
# 9982                         Bloody Vinyl Mixtape Vol. 1              Nitro
# 7506                         Bloody Vinyl Mixtape Vol. 1              Slait
# 9782                              Digital Jungle Mixtape              Salmo
# 416                               Digital Jungle Mixtape              Lazza
# 467                               Digital Jungle Mixtape              Lazza
# 9588                              Digital Jungle Mixtape          Dani Faiv
# 448                               Digital Jungle Mixtape              Lazza
# 1012                               Double Dragon Mixtape                Guè
# 985                                Double Dragon Mixtape                Guè
# 11134                              Double Dragon Mixtape          Marracash
# 7396                             Esse Magazine Freestyle           DrefGold
# 614                              Esse Magazine Freestyle             Nerone
# 428                              Esse Magazine Freestyle              Lazza
# 1231                             Esse Magazine Freestyle         Capo Plaza
# 10750                           Festival di Sanremo 2024      Fred De Palma
# 4416                            Festival di Sanremo 2024              Ghali
# 8466                                              Genesi      Achille Lauro
# 10799                                             Genesi      Fred De Palma
# 8144                                    Kill Phil Vol.1                Coez
# 2506                                    Kill Phil Vol.1            Mistaman
# 8008                                    Kill Phil Vol.1     Jack The Smoker
# 8009                                Monkee Bizniz Vol. 3    Jack The Smoker
# 4361                                Monkee Bizniz Vol. 3      Bassi Maestro
# 687                                 Monkee Bizniz Vol. 4            Babaman
# 4316                                Monkee Bizniz Vol. 4      Bassi Maestro
# 4333                                Monkee Bizniz Vol. 4      Bassi Maestro
# 4338                                Monkee Bizniz Vol. 4      Bassi Maestro
# 5346                                Monkee Bizniz Vol. 4             Baby K
# 7338                     One Take FM Free Mic - Season 3           Gemitaiz
# 5759                     One Take FM Free Mic - Season 3              Shade
# 5014                     One Take FM Free Mic - Season 3             Il Tre
# 2401                     One Take FM Free Mic - Season 3         Rocco Hunt
# 66                       One Take FM Free Mic - Season 6      Rosa Chemical
# 683                      One Take FM Free Mic - Season 6             Nerone
# 1928            PMC vs Club Dogo - The Official Mixtape           Club Dogo
# 1918            PMC vs Club Dogo - The Official Mixtape           Club Dogo
# 2572            PMC vs Club Dogo - The Official Mixtape               Inoki
# 2616            PMC vs Club Dogo - The Official Mixtape               Inoki
# 1865            PMC vs Club Dogo - The Official Mixtape           Club Dogo
# 1090            PMC vs Club Dogo - The Official Mixtape                 Guè
# 2760            PMC vs Club Dogo - The Official Mixtape       Jake La Furia
# 1027            PMC vs Club Dogo - The Official Mixtape                 Guè
# 8162            PMC vs Club Dogo - The Official Mixtape              Shablo
# 2762            PMC vs Club Dogo - The Official Mixtape       Jake La Furia
# 1926            PMC vs Club Dogo - The Official Mixtape           Club Dogo
# 6629            PMC vs Club Dogo - The Official Mixtape             Don Joe
# 2765            PMC vs Club Dogo - The Official Mixtape       Jake La Furia
# 10497                              Pompa il mio disstape       Mondo Marcio
# 10384                              Pompa il mio disstape       Mondo Marcio
# 6418                               Pompa il mio disstape             Entics
# 6361                               Pompa il mio disstape             Entics
# 6372                               Pompa il mio disstape             Entics
# 8605                         RED BULL 64 BARS, The Album              Rkomi
# 843                          RED BULL 64 BARS, The Album                Guè
# 7168                         RED BULL 64 BARS, The Album           Gemitaiz
# 73                           RED BULL 64 BARS, The Album               Beba
# 6506                         RED BULL 64 BARS, The Album              Ernia
# 11026                        RED BULL 64 BARS, The Album          Marracash
# 366                          RED BULL 64 BARS, The Album              Lazza
# 5597                         RED BULL 64 BARS, The Album            Geolier
# 11032                        RED BULL 64 BARS, The Album          Marracash
# 11071                                       Roccia Music          Marracash
# 11077                                       Roccia Music          Marracash
# 11126                                       Roccia Music          Marracash
# 11128                                       Roccia Music          Marracash
# 11135                                       Roccia Music          Marracash
# 11139                                       Roccia Music          Marracash
# 11145                                       Roccia Music          Marracash
# 2700                                        Roccia Music      Jake La Furia
# 11152                                       Roccia Music          Marracash
# 1053                                        Roccia Music                Guè
# 1073                                        Roccia Music                Guè
# 1877                                        Roccia Music          Club Dogo
# 10541                            Street Flava 2nd Avenue       Mondo Marcio
# 10681                            Street Flava 2nd Avenue       Mondo Marcio
# 6771                             Street Flava 2nd Avenue              Nesli
# 8785                             Street Flava 2nd Avenue         Cor Veleno
# 6617                                       Thori & Rocce            Don Joe
# 6616                                       Thori & Rocce            Don Joe
# 6612                                       Thori & Rocce            Don Joe
# 6624                                       Thori & Rocce            Don Joe
# 6626                                       Thori & Rocce            Don Joe
# 6628                                       Thori & Rocce            Don Joe
# 6630                                       Thori & Rocce            Don Joe
# 6636                                       Thori & Rocce            Don Joe
# 6620                                       Thori & Rocce            Don Joe
# 6610                                       Thori & Rocce            Don Joe
# 6607                                       Thori & Rocce            Don Joe
# 8155                                       Thori & Rocce             Shablo
# 6604                                       Thori & Rocce            Don Joe
# 6601                                       Thori & Rocce            Don Joe
# 6596                                       Thori & Rocce            Don Joe
# 6585                                       Thori & Rocce            Don Joe
# 6611                                       Thori & Rocce            Don Joe
# 9235   Torino Boys - Colonna Sonora Originale Del Fil...          Sottotono
# 1954   Torino Boys - Colonna Sonora Originale Del Fil...            La Pina
# 3664   Torino Boys - Colonna Sonora Originale Del Fil...              Neffa
# 6926                                        Undamento 01      Frah Quintale
# 8071                                        Undamento 01               Coez
# 8116                                        Undamento 01               Coez
#
#                                               title
# 5839                                Più Lei Che Noi
# 5792                              Quello che non ho
# 5766                                 L’ultima volta
# 5787                                     Malandrino
# 5793                                       Medaglia
# 5800                                         No Cap
# 5806                               Il Seme del Male
# 5825                             Per Tutta La Città
# 5831                           Il Seme del Male RMX
# 5842                             L’Ultima Volta RMX
# 5845                                          Crudo
# 5846                                        Ok Così
# 2699                                  Amore tossico
# 5782                                      Toro Loco
# 5779                                La mia prigione
# 5784                                     Maleducato
# 5778                                            666
# 5777                                  Lontano da me
# 5767                                 Renè & Francis
# 5768                                Broken Language
# 5774                                         Cowboy
# 5772                                 Gli amici miei
# 5770                                        Sparami
# 5769                                       No Insta
# 4881                                     Crash Test
# 9858                                  E’ il Momento
# 8146                                      Follow Me
# 8334                                 Lo Specialista
# 7358                                       Collasso
# 9183                              Colle Der Fomento
# 4261                                  Bassi Maestro
# 2633                             Freestyle (5° Dan)
# 2614                                      La Verità
# 2613                                 Com’è La Vista
# 2611                           Business Su Business
# 2621                                      Pole Pole
# 2595                               Ho Fatto Pratica
# 2560                              Lirico Alchimista
# 2583                                        In Volo
# 2575                              Polvere Di Strada
# 2561                         Mezzo Metro di Cannone
# 2557                                 Tutto Il Mondo
# 2541                              Vecchio Quartiere
# 2590                                       Since 95
# 8159                                Per Scaramanzia
# 9720                                            181
# 914                                            LOCO
# 7808                                     SOTTO VOCE
# 6566                                           APRI
# 425                                       MI ANTHEM
# 2701                                       M.S.O.M.
# 4499                                             EZ
# 9749                       BLOCCO 181 - Title Track
# 554                                         SICARIO
# 4612                                  Per Amore RMX
# 10630                             Patto col diavolo
# 5517                                        40 anni
# 6401                                           Sole
# 5983                                Autodistruzione
# 6258                                     Che notte!
# 1156                      Ba...ba...baciami piccina
# 5993                             Stelle nel flipper
# 4595                                       Profondo
# 10580                                 Mentre Scrivo
# 3317                                    Solo Per Me
# 7885                                      Freestyle
# 11154                                     Freestyle
# 7491                           99 Problemi (Remake)
# 7509                        Bloody Vinyl Mix Pt. II
# 7508                         Bloody Vinyl Mix Pt. I
# 7498                             Bloody Vinyl Intro
# 7502                                     Yoshimitsu
# 7503                                     Fotte Nada
# 7504                                     Plenilunio
# 7505                                      Toro Loco
# 7507                          The End of Everything
# 9982                              We takin’ it back
# 7506                                     Stonehenge
# 9782      Non ci resta che l’odio (DJ Slait MashUp)
# 416                                        I.B.F.M.
# 467                                       MOB (DJM)
# 9588                                        Zanzare
# 448                                     Tommy Jeans
# 1012                                          Boss!
# 985                            Che Nessuno Si Muova
# 11134                                   Casbah Flow
# 7396                    Esse Magazine Freestyle #20
# 614                      Sto Magazine Freestyle #12
# 428                       Sto Magazine Freestyle #8
# 1231                      Sto Magazine Freestyle #2
# 10750                         IL CIELO NON CI VUOLE
# 4416                                       Casa Mia
# 8466                 Scarpe Coi Tacchi #3 - La Fine
# 10799                                      F.D.P. 2
# 8144                           Da Grafic Revolution
# 2506                                   Vorrei Pt. 2
# 8008                               Non Ci Fermi Più
# 8009                              Chiama La Volante
# 4361                   Intro (Monkee Bizniz Vol. 3)
# 687                                             Lei
# 4316                                        Vecchio
# 4333                                  Siamo un mito
# 4338                             Vengo, Vedo, Vinco
# 5346                                 Nelle Mie Mani
# 7338                           One Take FM Free Mic
# 5759                           One Take FM Free Mic
# 5014                           One Take FM Free Mic
# 2401                           One Take FM Free Mic
# 66                             One Take FM Free Mic
# 683                            One Take FM Free Mic
# 1928                                     Ruff Combo
# 1918                                      La Triade
# 2572                         Cronache Di Resistenza
# 2616                                      Freestyle
# 1865                                 Tutto il mondo
# 1090                                   Killer Verse
# 2760                                    Plaza Music
# 1027                                Non Confonderti
# 8162                                          Intro
# 2762                            Il Suono Dei Nemici
# 1926                                 Hc Lover Click
# 6629                                Fuck the police
# 2765                                  Vida Loca Pt2
# 10497                        Un altro Punk in Città
# 10384  Cristiano cosa fai (Fine delle trasmissioni)
# 6418                              L’Uragano Matilda
# 6361                             Perdono x la Promo
# 6372                                   Inna My Yard
# 8605                        CUORE DOLLARI (64 Bars)
# 843                             VENEZUELA (64 Bars)
# 7168                    LA PROSSIMA VOLTA (64 Bars)
# 73                              WIMBLEDON (64 Bars)
# 6506                     LEWANDOWSKI VIII (64 Bars)
# 11026                             64 BARRE DI PAURA
# 366                           MEZZO SPORT (64 Bars)
# 5597                         RAP TUTORIAL (64 Bars)
# 11032                          64 BARRE DI VITTORIA
# 11071                                      Popolare
# 11077                           Chiedi Alla Polvere
# 11126                                    Nuovo Papa
# 11128                               Le Voglio Piene
# 11135                                  Roccia Music
# 11139                                      Il Gioco
# 11145                                        Regole
# 2700                                          Serpi
# 11152                                  Popolare RMX
# 1053                                        Castigo
# 1073                                  Sinfonia N. 7
# 1877                                 You Know NA-MI
# 10541                                L’Ultimo Ballo
# 10681                           Intro - Streetstyle
# 6771                               È Come L’Inverno
# 8785                                          Outro
# 6617                             Il resto del mondo
# 6616                                  Primo Carnera
# 6612                                  Vinci o perdi
# 6624                                Sono ancora qui
# 6626                                    Guarda bene
# 6628                       Thori & Rocce vs. Tayone
# 6630                                      Gran prix
# 6636                                        So Hard
# 6620                  Non mi fido di questo sistema
# 6610                                    Fuori luogo
# 6607                                       Sopranos
# 8155                                    Dai dai dai
# 6604                                Senza un domani
# 6601                                   Perché posso
# 6596                         L’ultimo giorno che ho
# 6585                    Le leggende non muoiono mai
# 6611                           La guerra dei poveri
# 9235                               La Vita Che Vivo
# 1954                                     Questa Fly
# 3664                               Ebby & Nike Pt.2
# 6926                                          Sosta
# 8071                                      Chiama Me
# 8116                     Pezzo di cuore (demo 2004)

# %%
#Vedo se ci sono album con lo stesso id e li printo

cols_to_check = ['album_name', 'primary_artist']

grouped = ds.groupby('id_album')[cols_to_check].agg(lambda x: x.unique())

conflicts = grouped[grouped.apply(lambda row: any(len(x) > 1 for x in row), axis=1)]

print(conflicts)
# Out:
#                                                   album_name  \
# id_album
# ALB156429        [Ma Vaffanculo, It's Snowing, Motherfucker]
# ALB275546                  [La maggior parte, Poco di Buono]
# ALB473208  [MALAVITA, Pt. 2 / HeadShot, Vol. 3, Il mio la...
# ALB504235              [Affetto Illimitato, Handmade Cities]
# ALB877400         [Allora ciao, Red Bull 64 Bars, The Album]
#
#                     primary_artist
# id_album
# ALB156429  [Skioffi, Rose Villain]
# ALB275546         [Ghemon, Caneda]
# ALB473208           [Inoki, Luchè]
# ALB504235           [Ensi, Entics]
# ALB877400           [Shade, Nitro]

# %%
# Controllo se ogni artista ha almeno un valore BPM valido, che è un prerequisito per calcolare successivamente 
# le medie (per artista) e imputare i dati mancanti per le feature melodiche

# raggruppo per artista e conto i bpm validi
valid_bpm_counts = ds.groupby('primary_artist')['bpm'].count()

# vediamo se sono tutti sopra lo 0
result = (valid_bpm_counts > 0).all()

print(f"Do all artists have at least one track with a valid BPM? {result}")
# Out:
# Do all artists have at least one track with a valid BPM? True

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # EDA artists.xml

# %%
df = pd.read_xml('artists.xml')
df.head()
# Out:
#      id_author           name gender  birth_date birth_place nationality  \
# 0  ART82291002       99 posse      M        None        None        None
# 1  ART53496045  achille lauro      M  1990-07-11      Verona      Italia
# 2  ART18853907           alfa      M        None        None        None
# 3  ART64265460      anna pepe      F        None        None        None
# 4  ART75741740    articolo 31      M        None        None        None
#
#                             description active_start  active_end province  \
# 0              gruppo musicale italiano   1991-01-01         NaN     None
# 1  cantautore e rapper italiano (1990-)   2012-01-01         NaN   Verona
# 2                                  None         None         NaN     None
# 3                                  None         None         NaN     None
# 4      gruppo musicale hip hop italiano   1990-01-01         NaN     None
#
#    region country   latitude  longitude
# 0    None    None        NaN        NaN
# 1  Veneto  Italia  45.442498  10.985738
# 2    None    None        NaN        NaN
# 3    None    None        NaN        NaN
# 4    None    None        NaN        NaN

# %%
df.shape
# Out:
# (104, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_author     104 non-null    object
#  1   name          104 non-null    object
#  2   gender        104 non-null    object
#  3   birth_date    73 non-null     object
#  4   birth_place   72 non-null     object
#  5   nationality   71 non-null     object
#  6   description   86 non-null     object
#  7   active_start  50 non-null     object
#  8   active_end    0 non-null      float64
#  9   province      70 non-null     object
#  10  region        68 non-null     object
#  11  country       70 non-null     object
#  12  latitude      72 non-null     float64
#  13  longitude     72 non-null     float64
# dtypes: float64(3), object(11)
# memory usage: 11.5+ KB

# %%
df.isnull().sum()
# Out:
# id_author         0
# name              0
# gender            0
# birth_date       31
# birth_place      32
# nationality      33
# description      18
# active_start     54
# active_end      104
# province         34
# region           36
# country          34
# latitude         32
# longitude        32
# dtype: int64

# %%
df.nunique()
# Out:
# id_author       104
# name            104
# gender            2
# birth_date       73
# birth_place      40
# nationality       2
# description      69
# active_start     24
# active_end        0
# province         26
# region           13
# country           1
# latitude         40
# longitude        40
# dtype: int64

# %%
df[df['birth_date'].isnull()].head(31)
# Out:
#        id_author               name gender birth_date birth_place nationality  \
# 0    ART82291002           99 posse      M       None        None        None
# 2    ART18853907               alfa      M       None        None        None
# 3    ART64265460          anna pepe      F       None        None        None
# 4    ART75741740        articolo 31      M       None        None        None
# 8    ART19605256               beba      F       None        None        None
# 9    ART02666525            bigmama      F       None        None        None
# 10   ART03111237             brusco      M       None        None        None
# 11   ART95365016           bushwaka      M       None        None        None
# 12   ART28846313             caneda      M       None        None        None
# 17   ART81071062          club dogo      M       None        None        None
# 19   ART85821920  colle der fomento      M       None        None        None
# 20   ART59609037         cor veleno      M       None        None        None
# 22   ART63985757     dargen d_amico      M       None        None        None
# 23   ART96068455     dark polo gang      M       None        None        None
# 24   ART52349448          doll kill      F       None        None        None
# 31   ART14073567            eva rea      F       None        None        None
# 42   ART04141409        guè pequeno      M       None        None        None
# 44   ART59593021            hindaco      F       None        None        None
# 50   ART88199433        joey funboy      F       None        None        None
# 51   ART07469279   johnny marsiglia      M       None        None        None
# 61   ART37807199             mike24      M       None        None        None
# 62   ART43601431          miss keta      F       None        None        None
# 63   ART51628788      miss simpatia      F       None        None        None
# 65   ART66452136            mistico      M       None        None        None
# 70   ART62385172             nerone      M       None        None        None
# 75   ART42220690             o zulù      M       None        None        None
# 78   ART87389753          priestess      F       None        None        None
# 87   ART56967402       samuel heron      M       None        None        None
# 92   ART41225226            skioffi      M       None        None        None
# 94   ART22979236          sottotono      M       None        None        None
# 102  ART71515715             yeиdry      F       None        None        None
#
#                                            description active_start  \
# 0                             gruppo musicale italiano   1991-01-01
# 2                                                 None         None
# 3                                                 None         None
# 4                     gruppo musicale hip hop italiano   1990-01-01
# 8                                              cognome         None
# 9                                                 None   2001-01-01
# 10                                             cognome         None
# 11                                                None         None
# 12                                             cognome         None
# 17                            gruppo musicale italiano         None
# 19                            gruppo musicale italiano         None
# 20                            gruppo musicale italiano   1993-01-01
# 22                                                None         None
# 23                            gruppo musicale italiano   2014-01-01
# 24                                                None         None
# 31                                                None         None
# 42                                                None         None
# 44                                                None         None
# 50                                                None         None
# 51                                                None         None
# 61                                                None         None
# 62                                                None         None
# 63                                                None         None
# 65   tipo di barca a vela usata nel XVIII e XIX secolo         None
# 70                     opera lirica di Pietro Mascagni         None
# 75                                                None         None
# 78                            gruppo musicale canadese   2003-01-01
# 87                                                None         None
# 92                                                None         None
# 94                            gruppo musicale italiano         None
# 102                                               None         None
#
#      active_end province region country  latitude  longitude
# 0           NaN     None   None    None       NaN        NaN
# 2           NaN     None   None    None       NaN        NaN
# 3           NaN     None   None    None       NaN        NaN
# 4           NaN     None   None    None       NaN        NaN
# 8           NaN     None   None    None       NaN        NaN
# 9           NaN     None   None    None       NaN        NaN
# 10          NaN     None   None    None       NaN        NaN
# 11          NaN     None   None    None       NaN        NaN
# 12          NaN     None   None    None       NaN        NaN
# 17          NaN     None   None    None       NaN        NaN
# 19          NaN     None   None    None       NaN        NaN
# 20          NaN     None   None    None       NaN        NaN
# 22          NaN     None   None    None       NaN        NaN
# 23          NaN     None   None    None       NaN        NaN
# 24          NaN     None   None    None       NaN        NaN
# 31          NaN     None   None    None       NaN        NaN
# 42          NaN     None   None    None       NaN        NaN
# 44          NaN     None   None    None       NaN        NaN
# 50          NaN     None   None    None       NaN        NaN
# 51          NaN     None   None    None       NaN        NaN
# 61          NaN     None   None    None       NaN        NaN
# 62          NaN     None   None    None       NaN        NaN
# 63          NaN     None   None    None       NaN        NaN
# 65          NaN     None   None    None       NaN        NaN
# 70          NaN     None   None    None       NaN        NaN
# 75          NaN     None   None    None       NaN        NaN
# 78          NaN     None   None    None       NaN        NaN
# 87          NaN     None   None    None       NaN        NaN
# 92          NaN     None   None    None       NaN        NaN
# 94          NaN     None   None    None       NaN        NaN
# 102         NaN     None   None    None       NaN        NaN

# %%
# Distribuzione per genere e nazionalità
df.groupby(['gender', 'nationality']).size().unstack(fill_value=0)
# Out:
# nationality  Argentina  Italia
# gender
# F                    0       6
# M                    1      64

# %%
# Età media artisti attivi
df['age'] = 2025 - pd.to_datetime(df['birth_date'], errors='coerce').dt.year
df.groupby('gender')['age'].agg(['mean', 'median', 'count'])
# Out:
#              mean  median  count
# gender
# F       35.500000    33.0      6
# M       38.363636    37.0     66

# %%
# Merge tracks.json per conteggio canzoni/streams per artista
artist_stats = ds.groupby('id_artist').agg({
    'id': 'count', 
    'streams@1month': 'sum'
}).rename(columns={'id': 'n_tracks', 'streams@1month': 'total_streams'})

df_plot = df.merge(artist_stats, left_on='id_author', right_index=True, how='left').fillna(0)

# plotto la mappa
fig = px.scatter_mapbox(df_plot, 
                       lat='latitude', lon='longitude',
                       size='n_tracks', color='total_streams',
                       hover_name='name',
                       color_continuous_scale='viridis',
                       size_max=30,
                       zoom=6, center={'lat': 42.5, 'lon': 12.5},
                       mapbox_style='open-street-map',
                       title='Artisti Rap Italiani: Canzoni e Streams per Regione')

fig.show()
# Out:
# C:\Users\alban\AppData\Local\Temp\ipykernel_11096\1143003986.py:13: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(df_plot,
